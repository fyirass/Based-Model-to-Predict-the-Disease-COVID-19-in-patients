# %% [markdown]
# # Reading Data and Importing libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
a=pd.read_csv("fichier_1.csv")
b=pd.read_csv("fichier_2.csv")
c=pd.read_csv("fichier_3.csv")
d=pd.read_csv("fichier_4.csv")
e=pd.read_csv("fichier_5.csv")
f=pd.read_csv("fichier_6.csv")
g=pd.read_csv("fichier_7.csv")
h=pd.read_csv("fichier_8.csv")
i=pd.read_csv("fichier_9.csv")
j=pd.read_csv("fichier_10.csv")
k=pd.read_csv("fichier_11.csv")

# %%
combine=[a,b,c,d,e,f,g,h,i,j,k]
dataset=pd.concat(combine)

# %%
dataset.head()
#y= covid_test results 
#les x :
#high_risk_exposure_occupation: 5edma fehe risque  ou 5tar 
#high_risk_interactions: barcha tawasel ben labed 
#diabetes : mridh be sokr 
#chd: mradh fil 9alb 
#htn: tension , andou eddem 
#cancer
#asthma:errabou ou dhi9 nfes 
#copd:مرض الانسداد الرئوي المزمن 
#autoimmune_dis:مرض المناعة الذاتية هو حالة يهاجم فيها جهاز المناعة جسمك عن طريق الخطأ.
#sys: pression mta dem 
#dia:essokr 
# rr :respiratory rate :A respiratory rate (RR) of 8-12 breaths per minute is recommended for patients
#sats:oxygen saturation : el 3abd 3adi meben 95-100%  
#rapid_flu_results : test rapide mta flu 
#rapid_strep_results: grejmou m9ay7a infecte 
# ctab:CTAB هو رمز لـ "فحص الرئة الطبيعي
#labored_respiration: dhi9 nfes  sou3oubet tanafos 
#rhonchi:الرونشي هي أصوات تنفسية خشنة وخشنة ، وتحدث عادة بسبب إفرازات في الشعب الهوائية.
#wheezes:to make a high, rough noise while breathing because of some breathing difficulty: I could hear the old man behind me wheezing. (kif li9belha)
#days_since_symptom_onset: nharat elli dhohrot fihom laradh أيام_منذ_الأعراض_الأولية
#cough_severity:yko7 yeser 
#fever:s5ana  el 7ommma 
#sob : shortness fo breath 
#sob_severity :barcha dhi9 nfes 
#diarrhea:jeryen kerch 
#muscle_sore : curbaturé
#sore_throat: m9aya7 
#cxr_......: radio taswira 3a rweri 
#er_referral:لإجراء تقييم متخصص
# Out:
#    batch_date             test_name  ... cxr_link er_referral
# 0  2020-04-07  SARS COV 2 RNA RTPCR  ...      NaN       False
# 1  2020-04-07       SARS-CoV-2, NAA  ...      NaN       False
# 2  2020-04-07  SARS CoV w/CoV 2 RNA  ...      NaN       False
# 3  2020-04-07  SARS COV 2 RNA RTPCR  ...      NaN       False
# 4  2020-04-07  SARS CoV w/CoV 2 RNA  ...      NaN       False
#
# [5 rows x 46 columns]

# %%
dataset.tail()
# Out:
#       batch_date        test_name  ... cxr_link er_referral
# 1441  2020-06-16  SARS-CoV-2, NAA  ...      NaN       False
# 1442  2020-06-16   SARS COV2 NAAT  ...      NaN       False
# 1443  2020-06-16   SARS COV2 NAAT  ...      NaN       False
# 1444  2020-06-16  SARS-CoV-2, NAA  ...      NaN       False
# 1445  2020-06-16   SARS COV2 NAAT  ...      NaN       False
#
# [5 rows x 46 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11169 entries, 0 to 1445
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   batch_date                     11169 non-null  object
#  1   test_name                      11169 non-null  object
#  2   swab_type                      11169 non-null  object
#  3   covid19_test_results           11169 non-null  object
#  4   age                            11169 non-null  int64
#  5   high_risk_exposure_occupation  11000 non-null  object
#  6   high_risk_interactions         9668 non-null   object
#  7   diabetes                       11169 non-null  bool
#  8   chd                            11169 non-null  bool
#  9   htn                            11169 non-null  bool
#  10  cancer                         11169 non-null  bool
#  11  asthma                         11169 non-null  bool
# ...

# %%
dataset.describe(include=object)
# Out:
#         batch_date  ...                                           cxr_link
# count        11169  ...                                                453
# unique          11  ...                                                451
# top     2020-05-05  ...  https://braid.health/viewer/study/d5753de2367a...
# freq          1601  ...                                                  2
#
# [4 rows x 29 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11169 entries, 0 to 1445
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   batch_date                     11169 non-null  object
#  1   test_name                      11169 non-null  object
#  2   swab_type                      11169 non-null  object
#  3   covid19_test_results           11169 non-null  object
#  4   age                            11169 non-null  int64
#  5   high_risk_exposure_occupation  11000 non-null  object
#  6   high_risk_interactions         9668 non-null   object
#  7   diabetes                       11169 non-null  bool
#  8   chd                            11169 non-null  bool
#  9   htn                            11169 non-null  bool
#  10  cancer                         11169 non-null  bool
#  11  asthma                         11169 non-null  bool
# ...

# %% [markdown]
# #EDA

# %%
# Check if there any missing values in train set
ax = dataset.isna().sum().sort_values().plot(kind = 'barh', figsize = (9, 10))
plt.title('Percentage of Missing Values Per Column in Train Set', fontdict={'size':15})
for p in ax.patches:
    percentage ='{:,.0f}%'.format((p.get_width()/dataset.shape[0])*100)
    width, height =p.get_width(),p.get_height()
    x=p.get_x()+width+0.02
    y=p.get_y()+height/2
    ax.annotate(percentage,(x,y))

# %%
dataset=dataset.drop(['rapid_strep_results','rapid_flu_results','cxr_label','cxr_impression','cxr_findings','cxr_link','sob_severity','cough_severity'],axis=1)

# %%
dataset.head()
# Out:
#    batch_date             test_name  ... sore_throat er_referral
# 0  2020-04-07  SARS COV 2 RNA RTPCR  ...       False       False
# 1  2020-04-07       SARS-CoV-2, NAA  ...       False       False
# 2  2020-04-07  SARS CoV w/CoV 2 RNA  ...         NaN       False
# 3  2020-04-07  SARS COV 2 RNA RTPCR  ...        True       False
# 4  2020-04-07  SARS CoV w/CoV 2 RNA  ...       False       False
#
# [5 rows x 38 columns]

# %%
dataset.isnull().sum()
# Out:
# batch_date                          0
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                      4627
# pulse                            4644
# sys                              4618
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11169 entries, 0 to 1445
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   batch_date                     11169 non-null  object
#  1   test_name                      11169 non-null  object
#  2   swab_type                      11169 non-null  object
#  3   covid19_test_results           11169 non-null  object
#  4   age                            11169 non-null  int64
#  5   high_risk_exposure_occupation  11000 non-null  object
#  6   high_risk_interactions         9668 non-null   object
#  7   diabetes                       11169 non-null  bool
#  8   chd                            11169 non-null  bool
#  9   htn                            11169 non-null  bool
#  10  cancer                         11169 non-null  bool
#  11  asthma                         11169 non-null  bool
# ...

# %%
g = sns.FacetGrid(dataset, col='covid19_test_results')
g.map(plt.hist, 'age', bins=20)
g

# %%
plt.figure(figsize=(7, 6))
sns.countplot(dataset.covid19_test_results)
plt.title('Target Variable Distribution');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataset['swab_type'].unique()
# Out:
# array(['Nasopharyngeal', 'Oropharyngeal', 'Nasal', 'anterior nares',
#        'anterior mares'], dtype=object)

# %%
# swab type  - 
plt.figure(figsize=(8, 7))
ax =sns.countplot(dataset.swab_type)
ax.set_xticklabels(['Nasopharyngeal', 'Oropharyngeal', 'Nasal', 'anterior nares','anterior mares'], rotation=45 )
plt.title('Distribution of swab type ', fontdict = {'size': 15});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataset['test_name'].unique()
# Out:
# array(['SARS COV 2 RNA RTPCR', 'SARS-CoV-2, NAA', 'SARS CoV w/CoV 2 RNA',
#        'Rapid COVID-19 Test', 'SARS COV2 NAAT'], dtype=object)

# %%
# high_risk_exposure_occupation  - 
plt.figure(figsize=(8, 7))
ax =sns.countplot(dataset.high_risk_exposure_occupation)
ax.set_xticklabels(['True','False'], rotation=45 )
plt.title('Distribution of high_risk_exposure_occupation', fontdict = {'size': 15});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11169 entries, 0 to 1445
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   batch_date                     11169 non-null  object
#  1   test_name                      11169 non-null  object
#  2   swab_type                      11169 non-null  object
#  3   covid19_test_results           11169 non-null  object
#  4   age                            11169 non-null  int64
#  5   high_risk_exposure_occupation  11000 non-null  object
#  6   high_risk_interactions         9668 non-null   object
#  7   diabetes                       11169 non-null  bool
#  8   chd                            11169 non-null  bool
#  9   htn                            11169 non-null  bool
#  10  cancer                         11169 non-null  bool
#  11  asthma                         11169 non-null  bool
# ...

# %%
dataset['diabetes'] = dataset['diabetes'].astype("uint8")
dataset['chd'] = dataset['chd'].astype("uint8")
dataset['htn'] = dataset['htn'].astype("uint8")
dataset['cancer'] = dataset['cancer'].astype("uint8")
dataset['asthma'] = dataset['asthma'].astype("uint8")
dataset['copd'] = dataset['copd'].astype("uint8")
dataset['autoimmune_dis'] = dataset['autoimmune_dis'].astype("uint8")
dataset['smoker'] = dataset['smoker'].astype("uint8")
dataset['er_referral'] = dataset['er_referral'].astype("uint8")

# %%
dataset.head()
# Out:
#    batch_date             test_name  ... sore_throat er_referral
# 0  2020-04-07  SARS COV 2 RNA RTPCR  ...       False           0
# 1  2020-04-07       SARS-CoV-2, NAA  ...       False           0
# 2  2020-04-07  SARS CoV w/CoV 2 RNA  ...         NaN           0
# 3  2020-04-07  SARS COV 2 RNA RTPCR  ...        True           0
# 4  2020-04-07  SARS CoV w/CoV 2 RNA  ...       False           0
#
# [5 rows x 38 columns]

# %%
dataset.isnull().sum()
# Out:
# batch_date                          0
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                      4627
# pulse                            4644
# sys                              4618
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# ...

# %%
# high_risk_exposure_occupation  - 
plt.figure(figsize=(8, 7))
ax =sns.countplot(dataset.high_risk_exposure_occupation)
ax.set_xticklabels([1,0], rotation=45 )
plt.title('Distribution of high_risk_exposure_occupation', fontdict = {'size': 15});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataset.head()
# Out:
#    batch_date             test_name  ... sore_throat er_referral
# 0  2020-04-07  SARS COV 2 RNA RTPCR  ...       False           0
# 1  2020-04-07       SARS-CoV-2, NAA  ...       False           0
# 2  2020-04-07  SARS CoV w/CoV 2 RNA  ...         NaN           0
# 3  2020-04-07  SARS COV 2 RNA RTPCR  ...        True           0
# 4  2020-04-07  SARS CoV w/CoV 2 RNA  ...       False           0
#
# [5 rows x 38 columns]

# %%
dataset['age'].unique()
# Out:
# array([58, 35, 12, 46, -1, 27, 29, 42, 44, 36, 62, 33,  6, 65, 75, 40, 48,
#        37, 38, 39, 56, 41, 61, 50, 20, 70, 24, 49, 22, 71, 23, 25, 52, 28,
#        32, 60, 26, 18, 59, 63, 73, 45, 57, 31, 17, 54, 47, 21, 19, 66, 34,
#        30, 79, 83, 51, 67, 82, 76, 55, 53, 43, 74, 72, 78,  5,  7, 64, 81,
#        86, 80, 77, 89, 90,  9, 68, 16, 69, 13, 11, 10, 14,  8, 88, 15, 84,
#        85, 87,  0,  4,  3, -2,  1,  2, -3])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11169 entries, 0 to 1445
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   batch_date                     11169 non-null  object
#  1   test_name                      11169 non-null  object
#  2   swab_type                      11169 non-null  object
#  3   covid19_test_results           11169 non-null  object
#  4   age                            11169 non-null  int64
#  5   high_risk_exposure_occupation  11000 non-null  object
#  6   high_risk_interactions         9668 non-null   object
#  7   diabetes                       11169 non-null  uint8
#  8   chd                            11169 non-null  uint8
#  9   htn                            11169 non-null  uint8
#  10  cancer                         11169 non-null  uint8
#  11  asthma                         11169 non-null  uint8
# ...

# %%
dataset.isnull().sum()
# Out:
# batch_date                          0
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                      4627
# pulse                            4644
# sys                              4618
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# ...

# %%
combina=[dataset]
for dataset in combina:    
    dataset.loc[ dataset['age'] <= 16, 'age'] = 0
    dataset.loc[(dataset['age'] > 16) & (dataset['age'] <= 32), 'age'] = 1
    dataset.loc[(dataset['age'] > 32) & (dataset['age'] <= 48), 'age'] = 2
    dataset.loc[(dataset['age'] > 48) & (dataset['age'] <= 64), 'age'] = 3
    dataset.loc[ dataset['age'] > 64, 'age']
dataset.head()
# Out:
#    batch_date             test_name  ... sore_throat er_referral
# 0  2020-04-07  SARS COV 2 RNA RTPCR  ...       False           0
# 1  2020-04-07       SARS-CoV-2, NAA  ...       False           0
# 2  2020-04-07  SARS CoV w/CoV 2 RNA  ...         NaN           0
# 3  2020-04-07  SARS COV 2 RNA RTPCR  ...        True           0
# 4  2020-04-07  SARS CoV w/CoV 2 RNA  ...       False           0
#
# [5 rows x 38 columns]

# %%
dataset.isnull().sum()
# Out:
# batch_date                          0
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                      4627
# pulse                            4644
# sys                              4618
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# ...

# %%
dataset.head()
# Out:
#    batch_date             test_name  ... sore_throat er_referral
# 0  2020-04-07  SARS COV 2 RNA RTPCR  ...       False           0
# 1  2020-04-07       SARS-CoV-2, NAA  ...       False           0
# 2  2020-04-07  SARS CoV w/CoV 2 RNA  ...         NaN           0
# 3  2020-04-07  SARS COV 2 RNA RTPCR  ...        True           0
# 4  2020-04-07  SARS CoV w/CoV 2 RNA  ...       False           0
#
# [5 rows x 38 columns]

# %%
dataset['covid19_test_results'][dataset['covid19_test_results'] == 'Negative'] = 0
dataset['covid19_test_results'][dataset['covid19_test_results']== 'Positive'] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dataset.head()
# Out:
#    batch_date             test_name  ... sore_throat er_referral
# 0  2020-04-07  SARS COV 2 RNA RTPCR  ...       False           0
# 1  2020-04-07       SARS-CoV-2, NAA  ...       False           0
# 2  2020-04-07  SARS CoV w/CoV 2 RNA  ...         NaN           0
# 3  2020-04-07  SARS COV 2 RNA RTPCR  ...        True           0
# 4  2020-04-07  SARS CoV w/CoV 2 RNA  ...       False           0
#
# [5 rows x 38 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11169 entries, 0 to 1445
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   batch_date                     11169 non-null  object
#  1   test_name                      11169 non-null  object
#  2   swab_type                      11169 non-null  object
#  3   covid19_test_results           11169 non-null  object
#  4   age                            11169 non-null  int64
#  5   high_risk_exposure_occupation  11000 non-null  object
#  6   high_risk_interactions         9668 non-null   object
#  7   diabetes                       11169 non-null  uint8
#  8   chd                            11169 non-null  uint8
#  9   htn                            11169 non-null  uint8
#  10  cancer                         11169 non-null  uint8
#  11  asthma                         11169 non-null  uint8
# ...

# %%
# Q1 - Has ATM/debit card
plt.figure(figsize=(8, 7))
ax =sns.countplot(dataset.ctab)
ax.set_xticklabels(['True','False','NaN'], rotation=45 )
plt.title('ctab', fontdict = {'size': 15});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataset.head()
# Out:
#    batch_date             test_name  ... sore_throat er_referral
# 0  2020-04-07  SARS COV 2 RNA RTPCR  ...       False           0
# 1  2020-04-07       SARS-CoV-2, NAA  ...       False           0
# 2  2020-04-07  SARS CoV w/CoV 2 RNA  ...         NaN           0
# 3  2020-04-07  SARS COV 2 RNA RTPCR  ...        True           0
# 4  2020-04-07  SARS CoV w/CoV 2 RNA  ...       False           0
#
# [5 rows x 38 columns]

# %%
dataset = dataset.drop(['batch_date'], axis=1)

# %%
dataset.head(4)
# Out:
#               test_name       swab_type  ... sore_throat  er_referral
# 0  SARS COV 2 RNA RTPCR  Nasopharyngeal  ...       False            0
# 1       SARS-CoV-2, NAA   Oropharyngeal  ...       False            0
# 2  SARS CoV w/CoV 2 RNA   Oropharyngeal  ...         NaN            0
# 3  SARS COV 2 RNA RTPCR  Nasopharyngeal  ...        True            0
#
# [4 rows x 37 columns]

# %%
dataset.isnull().sum()
# Out:
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                      4627
# pulse                            4644
# sys                              4618
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# days_since_symptom_onset         7596
# ...

# %%
dataset['cough'] = dataset['cough'].astype("bool")
dataset['cough'] = dataset['cough'].astype("uint8")
dataset['sob'] = dataset['sob'].astype("bool")
dataset['sob'] = dataset['sob'].astype("uint8")
dataset['diarrhea'] = dataset['diarrhea'].astype("bool")
dataset['diarrhea'] = dataset['diarrhea'].astype("uint8")
dataset['fatigue'] = dataset['fatigue'].astype("bool")
dataset['fatigue'] = dataset['fatigue'].astype("uint8")
dataset['headache'] = dataset['headache'].astype("bool")
dataset['headache'] = dataset['headache'].astype("uint8")
dataset['runny_nose'] = dataset['runny_nose'].astype("bool")
dataset['runny_nose'] = dataset['runny_nose'].astype("uint8")
dataset['muscle_sore'] = dataset['muscle_sore'].astype("bool")
dataset['muscle_sore'] = dataset['muscle_sore'].astype("uint8")

# %%
dataset.head()
# Out:
#               test_name       swab_type  ... sore_throat  er_referral
# 0  SARS COV 2 RNA RTPCR  Nasopharyngeal  ...       False            0
# 1       SARS-CoV-2, NAA   Oropharyngeal  ...       False            0
# 2  SARS CoV w/CoV 2 RNA   Oropharyngeal  ...         NaN            0
# 3  SARS COV 2 RNA RTPCR  Nasopharyngeal  ...        True            0
# 4  SARS CoV w/CoV 2 RNA  Nasopharyngeal  ...       False            0
#
# [5 rows x 37 columns]

# %%
dataset.isnull().sum()
# Out:
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                      4627
# pulse                            4644
# sys                              4618
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# days_since_symptom_onset         7596
# ...

# %%
def fill_with_random(df2, column):
    '''Fill `df2`'s column with name `column` with random data based on non-NaN data from `column`'''
    df = df2.copy()
    df[column] = df[column].apply(lambda x: np.random.choice(df[column].dropna().values) if np.isnan(x) else x)
    return df

# %%
plt.figure(figsize=(8, 7))
ax =sns.countplot(dataset.high_risk_interactions)
ax.set_xticklabels(['True','False'], rotation=45 )
plt.title('ss', fontdict = {'size': 15});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataset['high_risk_interactions'].isnull().sum()
# Out:
# 1501

# %%
dataset.tail()
# Out:
#             test_name       swab_type  ... sore_throat  er_referral
# 1441  SARS-CoV-2, NAA           Nasal  ...        True            0
# 1442   SARS COV2 NAAT  Nasopharyngeal  ...       False            0
# 1443   SARS COV2 NAAT  Nasopharyngeal  ...       False            0
# 1444  SARS-CoV-2, NAA           Nasal  ...        True            0
# 1445   SARS COV2 NAAT  Nasopharyngeal  ...       False            0
#
# [5 rows x 37 columns]

# %%
dataset.isna().sum()
# Out:
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                      4627
# pulse                            4644
# sys                              4618
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# days_since_symptom_onset         7596
# ...

# %%
dataset.sample(8)
# Out:
#             test_name       swab_type  ... sore_throat  er_referral
# 1356   SARS COV2 NAAT  Nasopharyngeal  ...       False            0
# 303   SARS-CoV-2, NAA           Nasal  ...       False            0
# 126    SARS COV2 NAAT  Nasopharyngeal  ...       False            0
# 454    SARS COV2 NAAT  Nasopharyngeal  ...       False            0
# 101   SARS-CoV-2, NAA           Nasal  ...       False            0
# 81     SARS COV2 NAAT  Nasopharyngeal  ...       False            0
# 719   SARS-CoV-2, NAA           Nasal  ...       False            0
# 1006   SARS COV2 NAAT  Nasopharyngeal  ...       False            0
#
# [8 rows x 37 columns]

# %%
dataset.size
# Out:
# 413253

# %%
dataset['temperature'].unique()
# Out:
# array([36.95, 36.75, 36.25, 36.7 , 37.35, 37.2 ,   nan, 37.3 , 37.  ,
#        37.4 , 36.4 , 37.8 , 37.1 , 36.8 , 36.65, 37.15, 36.6 , 38.  ,
#        36.9 , 37.25, 36.85, 37.5 , 36.3 , 38.4 , 37.45, 36.45, 36.5 ,
#        37.65, 35.8 , 35.9 , 38.45, 37.6 , 36.35, 38.25, 35.7 , 37.75,
#        37.7 , 38.35, 36.2 , 37.85, 38.15, 38.6 , 36.  , 38.3 , 35.65,
#        35.85, 38.1 , 37.95, 38.2 , 37.9 , 36.1 , 35.2 , 38.85, 38.8 ,
#        39.2 , 35.95, 36.15, 35.6 , 39.35, 34.95, 38.9 , 35.5 , 38.95,
#        39.4 , 35.35, 35.75, 35.4 ])

# %%
mean=dataset['temperature'].mean()
dataset['temperature'].fillna(mean,inplace=True)

# %%
dataset['temperature'].isnull().sum()
# Out:
# 0

# %%
dataset['temperature'].unique()
# Out:
# array([36.95     , 36.75     , 36.25     , 36.7      , 37.35     ,
#        37.2      , 36.8752675, 37.3      , 37.       , 37.4      ,
#        36.4      , 37.8      , 37.1      , 36.8      , 36.65     ,
#        37.15     , 36.6      , 38.       , 36.9      , 37.25     ,
#        36.85     , 37.5      , 36.3      , 38.4      , 37.45     ,
#        36.45     , 36.5      , 37.65     , 35.8      , 35.9      ,
#        38.45     , 37.6      , 36.35     , 38.25     , 35.7      ,
#        37.75     , 37.7      , 38.35     , 36.2      , 37.85     ,
#        38.15     , 38.6      , 36.       , 38.3      , 35.65     ,
#        35.85     , 38.1      , 37.95     , 38.2      , 37.9      ,
#        36.1      , 35.2      , 38.85     , 38.8      , 39.2      ,
#        35.95     , 36.15     , 35.6      , 39.35     , 34.95     ,
#        38.9      , 35.5      , 38.95     , 39.4      , 35.35     ,
#        35.75     , 35.4      ])

# %%
dataset.isnull().sum()
# Out:
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                         0
# pulse                            4644
# sys                              4618
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# days_since_symptom_onset         7596
# ...

# %%
g = sns.FacetGrid(dataset, col='covid19_test_results')
g.map(plt.hist, 'pulse', bins=20)

# %%
mean1=dataset['pulse'].mean()
dataset['pulse'].fillna(mean1,inplace=True)

# %%
dataset['pulse'].unique()
# Out:
# array([ 81.        ,  77.        ,  74.        ,  66.        ,
#         78.73011494, 117.        ,  95.        ,  72.        ,
#         92.        ,  99.        ,  90.        ,  93.        ,
#         65.        ,  86.        ,  76.        , 100.        ,
#        103.        ,  56.        , 113.        ,  79.        ,
#         73.        ,  67.        ,  87.        ,  60.        ,
#         80.        ,  82.        ,  70.        ,  75.        ,
#        124.        ,  97.        , 104.        ,  83.        ,
#         71.        ,  61.        ,  98.        ,  63.        ,
#         89.        ,  52.        ,  78.        ,  84.        ,
#        115.        , 101.        , 102.        , 107.        ,
#         94.        ,  64.        , 109.        , 106.        ,
#        110.        ,  85.        ,  69.        ,  68.        ,
#         88.        ,  96.        , 116.        ,  58.        ,
#        111.        ,  59.        ,  57.        , 119.        ,
# ...

# %%
dataset.isnull().sum()
# Out:
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                         0
# pulse                               0
# sys                              4618
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# days_since_symptom_onset         7596
# ...

# %%
dataset['sys'].unique()
# Out:
# array([126., 131., 122., 128.,  nan, 116., 133., 120., 135., 115.,  94.,
#        143., 151., 112., 145., 130., 137., 140., 138., 129.,  98., 119.,
#        124., 114., 165., 136., 121., 109., 118., 149., 142., 111., 104.,
#        113., 117., 156.,  96., 152., 101., 107.,  99., 147., 123., 144.,
#        108., 127., 141., 132., 153., 134., 146., 159., 158., 170., 205.,
#        106., 105., 157., 175., 103., 110.,  87., 148., 139.,  92., 160.,
#        150., 125., 102.,  91., 154.,  97., 190., 155.,  90., 100.,  88.,
#         95., 180.,  86.,  81.,  82.,  93., 185., 200.,  89., 195., 215.,
#        225.,  75.,  83., 235.])

# %%
median=dataset['sys'].median()
dataset['sys'].fillna(median,inplace=True)

# %%
dataset['sys'].unique()
# Out:
# array([126., 131., 122., 128., 124., 116., 133., 120., 135., 115.,  94.,
#        143., 151., 112., 145., 130., 137., 140., 138., 129.,  98., 119.,
#        114., 165., 136., 121., 109., 118., 149., 142., 111., 104., 113.,
#        117., 156.,  96., 152., 101., 107.,  99., 147., 123., 144., 108.,
#        127., 141., 132., 153., 134., 146., 159., 158., 170., 205., 106.,
#        105., 157., 175., 103., 110.,  87., 148., 139.,  92., 160., 150.,
#        125., 102.,  91., 154.,  97., 190., 155.,  90., 100.,  88.,  95.,
#        180.,  86.,  81.,  82.,  93., 185., 200.,  89., 195., 215., 225.,
#         75.,  83., 235.])

# %%
dataset.isnull().sum()
# Out:
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                         0
# pulse                               0
# sys                                 0
# dia                              4618
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# days_since_symptom_onset         7596
# ...

# %%
dataset.sample(3)
# Out:
#                 test_name       swab_type  ... sore_throat  er_referral
# 418   Rapid COVID-19 Test  Nasopharyngeal  ...       False            0
# 1367  Rapid COVID-19 Test  Nasopharyngeal  ...       False            0
# 1166       SARS COV2 NAAT  Nasopharyngeal  ...       False            0
#
# [3 rows x 37 columns]

# %%
dataset['dia'].unique()
# Out:
# array([ 82.,  86.,  73.,  76.,  nan,  81.,  78.,  68.,  59.,  87.,  97.,
#         84.,  79.,  89.,  80.,  96.,  88.,  66.,  67.,  72.,  85., 107.,
#        101.,  92.,  95.,  74.,  69.,  77.,  91.,  71.,  75.,  98.,  70.,
#        117.,  90.,  83.,  65., 118.,  64., 114.,  94.,  93., 119.,  62.,
#         99.,  58., 109.,  60.,  57., 104.,  61., 100.,  51.,  47.,  55.,
#        102., 112.,  56.,  63., 103., 106., 105.,  49.,  48., 108.,  43.,
#         52.,  54., 115., 116., 135., 110.,  53.,  50.,  40., 120., 111.,
#        130., 113.,  41.,  36.])

# %%
mean2=dataset['dia'].mean()
dataset['dia'].fillna(mean2,inplace=True)

# %%
dataset['dia'].unique()
# Out:
# array([ 82.        ,  86.        ,  73.        ,  76.        ,
#         79.70645703,  81.        ,  78.        ,  68.        ,
#         59.        ,  87.        ,  97.        ,  84.        ,
#         79.        ,  89.        ,  80.        ,  96.        ,
#         88.        ,  66.        ,  67.        ,  72.        ,
#         85.        , 107.        , 101.        ,  92.        ,
#         95.        ,  74.        ,  69.        ,  77.        ,
#         91.        ,  71.        ,  75.        ,  98.        ,
#         70.        , 117.        ,  90.        ,  83.        ,
#         65.        , 118.        ,  64.        , 114.        ,
#         94.        ,  93.        , 119.        ,  62.        ,
#         99.        ,  58.        , 109.        ,  60.        ,
#         57.        , 104.        ,  61.        , 100.        ,
#         51.        ,  47.        ,  55.        , 102.        ,
#        112.        ,  56.        ,  63.        , 103.        ,
# ...

# %%
dataset.isna().sum()
# Out:
# test_name                           0
# swab_type                           0
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                         0
# pulse                               0
# sys                                 0
# dia                                 0
# rr                               5407
# sats                             4783
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# days_since_symptom_onset         7596
# ...

# %%
dataset['sats'].unique()
# Out:
# array([ 97.,  98., 100.,  nan,  94.,  96.,  99.,  95.,  93.,  92.,  90.,
#         87.,  76.,  81.,  91.])

# %%
mean3=dataset['sats'].mean()
dataset['sats'].fillna(mean3,inplace=True)
dataset['sats'].unique()
# Out:
# array([ 97.        ,  98.        , 100.        ,  98.10898841,
#         94.        ,  96.        ,  99.        ,  95.        ,
#         93.        ,  92.        ,  90.        ,  87.        ,
#         76.        ,  81.        ,  91.        ])

# %%
dataset['fever'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %%
dataset.describe(include=object)
# Out:
#                   test_name       swab_type  ...  loss_of_taste sore_throat
# count                 11169           11169  ...          10979       10986
# unique                    5               5  ...              2           2
# top     Rapid COVID-19 Test  Nasopharyngeal  ...          False       False
# freq                   3714            6248  ...          10744        9666
#
# [4 rows x 13 columns]

# %%
r=dataset['rr'].median()
dataset['rr'].replace(np.nan,r,inplace=True)
dataset['rr'].isna().sum()
# Out:
# 0

# %%
dataset.drop(['test_name','swab_type'],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#   covid19_test_results  age  ... sore_throat er_referral
# 0                    0    3  ...       False           0
# 1                    0    2  ...       False           0
# 2                    0    0  ...         NaN           0
# 3                    0    2  ...        True           0
# 4                    0    0  ...       False           0
#
# [5 rows x 35 columns]

# %%
dataset['days_since_symptom_onset'].unique()
# Out:
# array([ 28.,  nan,   3.,   4.,  10.,   5.,   7.,  14.,   2.,  30.,  21.,
#          1.,  70.,  60.,  90., 150.,  35.,  49., 120., 300., 210.])

# %%
days=dataset['days_since_symptom_onset'].median()
dataset['days_since_symptom_onset'].replace(np.nan,days,inplace=True)
dataset['days_since_symptom_onset'].isna().sum()
# Out:
# 0

# %%
dataset['days_since_symptom_onset'].unique()
# Out:
# array([ 28.,   4.,   3.,  10.,   5.,   7.,  14.,   2.,  30.,  21.,   1.,
#         70.,  60.,  90., 150.,  35.,  49., 120., 300., 210.])

# %%
dataset.isna().sum()
# Out:
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                         0
# pulse                               0
# sys                                 0
# dia                                 0
# rr                                  0
# sats                                0
# ctab                             5293
# labored_respiration              4146
# rhonchi                          6658
# wheezes                          6344
# days_since_symptom_onset            0
# cough                               0
# fever                            2532
# ...

# %%
corrmat = dataset.corr() # effectuer le comatrice de correlation 
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
dataset.columns
# Out:
# Index(['covid19_test_results', 'age', 'high_risk_exposure_occupation',
#        'high_risk_interactions', 'diabetes', 'chd', 'htn', 'cancer', 'asthma',
#        'copd', 'autoimmune_dis', 'smoker', 'temperature', 'pulse', 'sys',
#        'dia', 'rr', 'sats', 'ctab', 'labored_respiration', 'rhonchi',
#        'wheezes', 'days_since_symptom_onset', 'cough', 'fever', 'sob',
#        'diarrhea', 'fatigue', 'headache', 'loss_of_smell', 'loss_of_taste',
#        'runny_nose', 'muscle_sore', 'sore_throat', 'er_referral'],
#       dtype='object')

# %%
dataset.head()
# Out:
#   covid19_test_results  age  ... sore_throat er_referral
# 0                    0    3  ...       False           0
# 1                    0    2  ...       False           0
# 2                    0    0  ...         NaN           0
# 3                    0    2  ...        True           0
# 4                    0    0  ...       False           0
#
# [5 rows x 35 columns]

# %%
dataset.drop(['rhonchi'],axis=1,inplace=True)
dataset.head(4)
# Out:
#   covid19_test_results  age  ... sore_throat er_referral
# 0                    0    3  ...       False           0
# 1                    0    2  ...       False           0
# 2                    0    0  ...         NaN           0
# 3                    0    2  ...        True           0
#
# [4 rows x 34 columns]

# %%
dataset.isnull().sum()
# Out:
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                         0
# pulse                               0
# sys                                 0
# dia                                 0
# rr                                  0
# sats                                0
# ctab                             5293
# labored_respiration              4146
# wheezes                          6344
# days_since_symptom_onset            0
# cough                               0
# fever                            2532
# sob                                 0
# ...

# %%
def fill_with_random(df3, column):
    '''Fill `df2`'s column with name `column` with random data based on non-NaN data from `column`'''
    df = df3.copy()
    df[column] = df[column].apply(lambda x: np.random.choice(df[column].dropna().values) if np.isnan(x) else x)
    return df

# %%
dataset=fill_with_random(dataset,'fever')

# %%
dataset.head()
# Out:
#   covid19_test_results  age  ... sore_throat er_referral
# 0                    0    3  ...       False           0
# 1                    0    2  ...       False           0
# 2                    0    0  ...         NaN           0
# 3                    0    2  ...        True           0
# 4                    0    0  ...       False           0
#
# [5 rows x 34 columns]

# %%
plt.figure(figsize=(8, 7))
ax =sns.countplot(dataset.fever)
ax.set_xticklabels(['True','False'], rotation=45 )
plt.title('ss', fontdict = {'size': 15});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataset.tail()
# Out:
#      covid19_test_results  age  ... sore_throat er_referral
# 1441                    0    1  ...        True           0
# 1442                    1    1  ...       False           0
# 1443                    0    2  ...       False           0
# 1444                    0    2  ...        True           0
# 1445                    0   80  ...       False           0
#
# [5 rows x 34 columns]

# %%
dataset.isna().sum()
# Out:
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation     169
# high_risk_interactions           1501
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                         0
# pulse                               0
# sys                                 0
# dia                                 0
# rr                                  0
# sats                                0
# ctab                             5293
# labored_respiration              4146
# wheezes                          6344
# days_since_symptom_onset            0
# cough                               0
# fever                               0
# sob                                 0
# ...

# %%
dataset['labored_respiration'].unique()
# Out:
# array([False, nan, True], dtype=object)

# %%
dataset.head()
# Out:
#   covid19_test_results  age  ... sore_throat er_referral
# 0                    0    3  ...       False           0
# 1                    0    2  ...       False           0
# 2                    0    0  ...         NaN           0
# 3                    0    2  ...        True           0
# 4                    0    0  ...       False           0
#
# [5 rows x 34 columns]

# %%
dataset.size
# Out:
# 379746

# %%
len (dataset)
# Out:
# 11169

# %%
L=dataset[['sore_throat','loss_of_taste','loss_of_smell','labored_respiration','high_risk_exposure_occupation','high_risk_interactions']]

# %%
K=0
for i in range (11169) :
    for j in L :
        
        if ((pd.isna(dataset.iloc[i][j]))is True):
            K=K+1
            if (dataset.iloc[i]['covid19_test_results']=='Positive'):
                dataset[j]=  dataset[j].replace(np.nan,'True')

            else:
            
                dataset[j]=  dataset[j].replace(np.nan,'False')
print(K)
# Out:
# 6

# %%
dataset.isnull().sum()
# Out:
# covid19_test_results                0
# age                                 0
# high_risk_exposure_occupation       0
# high_risk_interactions              0
# diabetes                            0
# chd                                 0
# htn                                 0
# cancer                              0
# asthma                              0
# copd                                0
# autoimmune_dis                      0
# smoker                              0
# temperature                         0
# pulse                               0
# sys                                 0
# dia                                 0
# rr                                  0
# sats                                0
# ctab                             5293
# labored_respiration                 0
# wheezes                          6344
# days_since_symptom_onset            0
# cough                               0
# fever                               0
# sob                                 0
# ...

# %%
dataset.head()
# Out:
#   covid19_test_results  age  ... sore_throat er_referral
# 0                    0    3  ...       False           0
# 1                    0    2  ...       False           0
# 2                    0    0  ...       False           0
# 3                    0    2  ...        True           0
# 4                    0    0  ...       False           0
#
# [5 rows x 34 columns]

# %%
plt.figure(figsize=(8, 7))
ax =sns.countplot(dataset.wheezes)
ax.set_xticklabels(['True','False'], rotation=45 )
plt.title('ss', fontdict = {'size': 15});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataset=fill_with_random(dataset,'wheezes')

# %%
dataset.drop(['ctab'],axis=1,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# covid19_test_results             0
# age                              0
# high_risk_exposure_occupation    0
# high_risk_interactions           0
# diabetes                         0
# chd                              0
# htn                              0
# cancer                           0
# asthma                           0
# copd                             0
# autoimmune_dis                   0
# smoker                           0
# temperature                      0
# pulse                            0
# sys                              0
# dia                              0
# rr                               0
# sats                             0
# labored_respiration              0
# wheezes                          0
# days_since_symptom_onset         0
# cough                            0
# fever                            0
# sob                              0
# diarrhea                         0
# fatigue                          0
# headache                         0
# ...

# %%
dataset.head(4)
# Out:
#   covid19_test_results  age  ... sore_throat er_referral
# 0                    0    3  ...       False           0
# 1                    0    2  ...       False           0
# 2                    0    0  ...       False           0
# 3                    0    2  ...        True           0
#
# [4 rows x 33 columns]

# %%
dataset['high_risk_exposure_occupation'] = dataset['high_risk_exposure_occupation'].astype("bool")
dataset['high_risk_exposure_occupation'] = dataset['high_risk_exposure_occupation'].astype("uint8")
dataset['high_risk_interactions'] = dataset['high_risk_interactions'].astype("bool")
dataset['high_risk_interactions'] = dataset['high_risk_interactions'].astype("uint8")
dataset['labored_respiration'] = dataset['labored_respiration'].astype("bool")
dataset['labored_respiration'] = dataset['labored_respiration'].astype("uint8")
dataset['wheezes'] = dataset['wheezes'].astype("bool")
dataset['wheezes'] = dataset['wheezes'].astype("uint8")
dataset['fever'] = dataset['fever'].astype("bool")
dataset['fever'] = dataset['fever'].astype("uint8")
dataset['loss_of_smell'] = dataset['loss_of_smell'].astype("bool")
dataset['loss_of_smell'] = dataset['loss_of_smell'].astype("uint8")
dataset['loss_of_taste'] = dataset['loss_of_taste'].astype("bool")
dataset['loss_of_taste'] = dataset['loss_of_taste'].astype("uint8")
dataset['sore_throat'] = dataset['sore_throat'].astype("bool")
dataset['sore_throat'] = dataset['sore_throat'].astype("uint8")

# %%
dataset['covid19_test_results'] = dataset['covid19_test_results'].astype("uint8")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11169 entries, 0 to 1445
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   covid19_test_results           11169 non-null  uint8
#  1   age                            11169 non-null  int64
#  2   high_risk_exposure_occupation  11169 non-null  uint8
#  3   high_risk_interactions         11169 non-null  uint8
#  4   diabetes                       11169 non-null  uint8
#  5   chd                            11169 non-null  uint8
#  6   htn                            11169 non-null  uint8
#  7   cancer                         11169 non-null  uint8
#  8   asthma                         11169 non-null  uint8
#  9   copd                           11169 non-null  uint8
#  10  autoimmune_dis                 11169 non-null  uint8
#  11  smoker                         11169 non-null  uint8
# ...

# %%
dataset.columns
# Out:
# Index(['covid19_test_results', 'age', 'high_risk_exposure_occupation',
#        'high_risk_interactions', 'diabetes', 'chd', 'htn', 'cancer', 'asthma',
#        'copd', 'autoimmune_dis', 'smoker', 'temperature', 'pulse', 'sys',
#        'dia', 'rr', 'sats', 'labored_respiration', 'wheezes',
#        'days_since_symptom_onset', 'cough', 'fever', 'sob', 'diarrhea',
#        'fatigue', 'headache', 'loss_of_smell', 'loss_of_taste', 'runny_nose',
#        'muscle_sore', 'sore_throat', 'er_referral'],
#       dtype='object')

# %% [markdown]
# #Machine learning

# %% [markdown]
# ## Data Preparation

# %%
x = dataset[['pulse','sys','temperature','smoker','rr','wheezes','dia','labored_respiration', 'high_risk_exposure_occupation','days_since_symptom_onset','loss_of_smell', 'muscle_sore','fatigue','diarrhea']]
y = dataset['covid19_test_results']
x.head()
# Out:
#        pulse    sys  temperature  ...  muscle_sore  fatigue  diarrhea
# 0  81.000000  126.0        36.95  ...            0        0         0
# 1  77.000000  131.0        36.75  ...            0        0         0
# 2  74.000000  122.0        36.95  ...            1        1         1
# 3  66.000000  128.0        36.75  ...            0        1         0
# 4  78.730115  124.0        36.25  ...            0        0         0
#
# [5 rows x 14 columns]

# %%
 #Method 2: Normalisation, (entre 0 et 1)
#from sklearn.preprocessing import MinMaxScaler
#mms = MinMaxScaler()
#x[['temperature','pulse','sys','dia','rr']] = mms.fit_transform(x[['temperature','pulse','sys','dia','rr']])
#y = mms.fit_transform(dataset[['covid19_test_results']])
#x.head(3)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1441    0
# 1442    1
# 1443    0
# 1444    0
# 1445    0
# Name: covid19_test_results, Length: 11169, dtype: uint8

# %% [markdown]
# ##Models

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=50)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.metrics import classification_report
predictions_tree = tree.predict(X_test)
print(classification_report(y_test, predictions_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2162
#            1       0.10      0.10      0.10        72
#
#     accuracy                           0.94      2234
#    macro avg       0.53      0.53      0.53      2234
# weighted avg       0.94      0.94      0.94      2234

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
print(model)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
from sklearn.metrics import classification_report
model_pred = model.predict(X_test)
print(classification_report(y_test, model_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      2162
#            1       0.00      0.00      0.00        72
#
#     accuracy                           0.97      2234
#    macro avg       0.48      0.50      0.49      2234
# weighted avg       0.94      0.97      0.95      2234
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(model.score(X_train, y_train), model.score(X_test, y_test)) #.score calculates the accuracy of the model
# Out:
# 0.9732512590934527 0.9677708146821844

# %%
acc1 = accuracy_score(y_test,predictions_tree)
print(acc1)
# Out:
# 0.9418084153983886

# %%
tree.feature_importances_ # 9adeh les valeurs ta3 kol feature 9adeh 3awnet
# Out:
# array([0.16552389, 0.19332697, 0.14078903, 0.00978536, 0.05266917,
#        0.05243833, 0.16963959, 0.01863696, 0.02206052, 0.11055641,
#        0.00788566, 0.03110664, 0.01841271, 0.00716877])

# %%
dataset.columns # ta3tini esemi les colonnes b nafs nidham ta3 feature_importances_
# Out:
# Index(['covid19_test_results', 'age', 'high_risk_exposure_occupation',
#        'high_risk_interactions', 'diabetes', 'chd', 'htn', 'cancer', 'asthma',
#        'copd', 'autoimmune_dis', 'smoker', 'temperature', 'pulse', 'sys',
#        'dia', 'rr', 'sats', 'labored_respiration', 'wheezes',
#        'days_since_symptom_onset', 'cough', 'fever', 'sob', 'diarrhea',
#        'fatigue', 'headache', 'loss_of_smell', 'loss_of_taste', 'runny_nose',
#        'muscle_sore', 'sore_throat', 'er_referral'],
#       dtype='object')

# %%
sorted(list(zip(tree.feature_importances_, dataset.columns)), reverse=True)
# ya3mali list ta3 kol colonne chnaw importance te3ha w mnadhma min a3la wa7da li a9al wa7da
# Out:
# [(0.19332696617377526, 'age'),
#  (0.16963958921702463, 'htn'),
#  (0.16552388638315588, 'covid19_test_results'),
#  (0.1407890255425325, 'high_risk_exposure_occupation'),
#  (0.11055640506127465, 'copd'),
#  (0.05266917178917469, 'diabetes'),
#  (0.05243832817291918, 'chd'),
#  (0.031106638601739203, 'smoker'),
#  (0.022060522225579013, 'asthma'),
#  (0.018636961643333335, 'cancer'),
#  (0.018412712628983426, 'temperature'),
#  (0.009785363289198813, 'high_risk_interactions'),
#  (0.007885662149420363, 'autoimmune_dis'),
#  (0.007168767121889186, 'pulse')]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
knn_roc_auc = roc_auc_score(y_test, tree.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, tree.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='knn (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taux de faux positifs')
plt.ylabel('Taux de vrais positifs')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %%
# Making the Confusion Matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predictions_tree)
sns.heatmap(cm,annot=True)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9113697403760072

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
knn_roc_auc = roc_auc_score(y_test, classifier.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, classifier.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='naive baise  (area = %0.2f)' % knn_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taux de faux positifs')
plt.ylabel('Taux de vrais positifs')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
print(classifier.score(X_test, y_test))
# Out:
# 0.9113697403760072

# %%
from joblib import dump

dump(classifier , 'sars_cov2_pred_gaussien_nb.joblib')
# Out:
# ['sars_cov2_pred_gaussien_nb.joblib']

# %% [markdown]
# ### Deployment on a web server (APP)

# %%
from joblib import load

def get_data():
  # method 1: API
  # method 2: Database
  return features
  
def preprocess_data(features):
  # Missing data
  # Type casting
  # Normalisation & standardisation
  return pre_processed_data

def main():
  # Model Loading
  model = load('sars_cov2_pred.joblib')

  # Getting the data to predict on
  features = get_data()
  pre_processed_data = preprocess(features)

  # Inference / Predict
  return model.predict(pre_processed_data)

# %%
import pickle 
pickle.dump(classifier,open('sars_cov2_pred_gaussien_nb.pkl','wb'))

# %%
x.tail()
# Out:
#       pulse    sys  temperature  ...  muscle_sore  fatigue  diarrhea
# 1441   94.0  123.0        36.75  ...            0        0         0
# 1442   67.0  111.0        37.10  ...            0        0         0
# 1443   84.0  106.0        36.85  ...            0        0         0
# 1444   81.0  123.0        37.45  ...            1        0         1
# 1445   68.0  160.0        36.60  ...            0        0         0
#
# [5 rows x 14 columns]

# %%
y.tail()
# Out:
# 1441    0
# 1442    1
# 1443    0
# 1444    0
# 1445    0
# Name: covid19_test_results, dtype: uint8
